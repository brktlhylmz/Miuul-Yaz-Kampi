# %%
#Kütüphanelerin yüklenmesi
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#Görev 1: 
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Görev 2: 
df["sex"].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
#Görev 3: 
for i in df.columns:
    print(f"{i.upper()} Sütunundaki Unique Değerlerin Toplam Sayısı:\n {df[i].nunique()} ")
# Out:
# SURVIVED Sütunundaki Unique Değerlerin Toplam Sayısı:
#  2
# PCLASS Sütunundaki Unique Değerlerin Toplam Sayısı:
#  3
# SEX Sütunundaki Unique Değerlerin Toplam Sayısı:
#  2
# AGE Sütunundaki Unique Değerlerin Toplam Sayısı:
#  88
# SIBSP Sütunundaki Unique Değerlerin Toplam Sayısı:
#  7
# PARCH Sütunundaki Unique Değerlerin Toplam Sayısı:
#  7
# FARE Sütunundaki Unique Değerlerin Toplam Sayısı:
#  248
# EMBARKED Sütunundaki Unique Değerlerin Toplam Sayısı:
#  3
# CLASS Sütunundaki Unique Değerlerin Toplam Sayısı:
#  3
# WHO Sütunundaki Unique Değerlerin Toplam Sayısı:
#  3
# ADULT_MALE Sütunundaki Unique Değerlerin Toplam Sayısı:
#  2
# DECK Sütunundaki Unique Değerlerin Toplam Sayısı:
#  7
# EMBARK_TOWN Sütunundaki Unique Değerlerin Toplam Sayısı:
#  3
# ALIVE Sütunundaki Unique Değerlerin Toplam Sayısı:
#  2
# ALONE Sütunundaki Unique Değerlerin Toplam Sayısı:
#  2

# %%
#Görev 4: 
print(f"{df.pclass.unique()} değerleri Unique değerlerdir.")
# Out:
# [3 1 2] değerleri Unique değerlerdir.

# %%
#Görev 5: 
print(f"{df.pclass.unique()} Pclass Sütununun Unique değerlerdir.\n{df.parch.unique()} Parch Sütununun Unique değerlerdir.")
# Out:
# [3 1 2] Pclass Sütununun Unique değerlerdir.
# [0 1 2 5 3 4 6] Parch Sütununun Unique değerlerdir.

# %%
#Görev 6: 
print(f"Embarked Sütununun değişim öncesi tipi {df.dtypes[7]}'dir...")
df["embarked"] = df.embarked.astype("category")
print(f"Embarked Sütununun değişim sonrası tipi {df.dtypes[7]}'dir...")
# Out:
# Embarked Sütununun değişim öncesi tipi object'dir...
# Embarked Sütununun değişim sonrası tipi category'dir...

# %%
#Görev 7: 
df[df.embarked=="C"]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 1           1       1  female  38.00      1      0   71.2833        C   First
# 9           1       2  female  14.00      1      0   30.0708        C  Second
# 19          1       3  female    NaN      0      0    7.2250        C   Third
# 26          0       3    male    NaN      0      0    7.2250        C   Third
# 30          0       1    male  40.00      0      0   27.7208        C   First
# 31          1       1  female    NaN      1      0  146.5208        C   First
# 34          0       1    male  28.00      1      0   82.1708        C   First
# 36          1       3    male    NaN      0      0    7.2292        C   Third
# 39          1       3  female  14.00      1      0   11.2417        C   Third
# 42          0       3    male    NaN      0      0    7.8958        C   Third
# 43          1       2  female   3.00      1      2   41.5792        C  Second
# ...

# %%
#Görev 8: 
df[df.embarked!="S"]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 1           1       1  female  38.00      1      0   71.2833        C   First
# 5           0       3    male    NaN      0      0    8.4583        Q   Third
# 9           1       2  female  14.00      1      0   30.0708        C  Second
# 16          0       3    male   2.00      4      1   29.1250        Q   Third
# 19          1       3  female    NaN      0      0    7.2250        C   Third
# 22          1       3  female  15.00      0      0    8.0292        Q   Third
# 26          0       3    male    NaN      0      0    7.2250        C   Third
# 28          1       3  female    NaN      0      0    7.8792        Q   Third
# 30          0       1    male  40.00      0      0   27.7208        C   First
# 31          1       1  female    NaN      1      0  146.5208        C   First
# 32          1       3  female    NaN      0      0    7.7500        Q   Third
# ...

# %%
#Görev 9: 
df[df.sex=="female"][df.age<30]
# Out:
# C:\Users\90538\AppData\Local\Temp\ipykernel_5112\2877879567.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.sex=="female"][df.age<30]
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 2           1       3  female  26.00      0      0    7.9250        S   Third
# 8           1       3  female  27.00      0      2   11.1333        S   Third
# 9           1       2  female  14.00      1      0   30.0708        C  Second
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# 14          0       3  female  14.00      0      0    7.8542        S   Third
# 22          1       3  female  15.00      0      0    8.0292        Q   Third
# 24          0       3  female   8.00      3      1   21.0750        S   Third
# 38          0       3  female  18.00      2      0   18.0000        S   Third
# 39          1       3  female  14.00      1      0   11.2417        C   Third
# ...

# %%
#Görev 10: 
fare = df[df.fare>500]
age = df[df.age>70]
pd.concat([fare,age])
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 96          0       1    male  71.0      0      0   34.6542        C  First
# 116         0       3    male  70.5      0      0    7.7500        Q  Third
# 493         0       1    male  71.0      0      0   49.5042        C  First
# 630         1       1    male  80.0      0      0   30.0000        S  First
# 851         0       3    male  74.0      0      0    7.7750        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 258  woman       False  NaN    Cherbourg   yes   True
# 679    man        True    B    Cherbourg   yes  False
# 737    man        True    B    Cherbourg   yes   True
# 96     man        True    A    Cherbourg    no   True
# ...

# %%
#Görev 11: 
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#Görev 12: 
df.drop(columns=["who"],axis=1,inplace=True)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
#Görev 13: 
print(f"İşlemden önce {df.deck.isna().sum()} adet boş değer var.")
df.deck.fillna(df.deck.mode()[0],inplace=True)
print(f"İşlemden sonra {df.deck.isna().sum()} adet boş değer var.")
# Out:
# İşlemden önce 688 adet boş değer var.
# İşlemden sonra 0 adet boş değer var.

# %%
#Görev 14: 
print(f"İşlemden önce {df.age.isna().sum()} adet boş değer var.")
df.age.fillna(df.age.median(),inplace=True)
print(f"İşlemden sonra {df.age.isna().sum()} adet boş değer var.")
# Out:
# İşlemden önce 177 adet boş değer var.
# İşlemden sonra 0 adet boş değer var.

# %%
#Görev 15: 
print(df.groupby("survived")["age"].sum())
print(df.groupby("survived")["age"].count())
print(df.groupby("survived")["age"].mean())
print(df.groupby("survived")["pclass"].sum())
print(df.groupby("survived")["pclass"].count())
print(df.groupby("survived")["pclass"].sum())
# Out:
# survived
# 0    16485.50
# 1     9675.67
# Name: age, dtype: float64
# survived
# 0    549
# 1    342
# Name: age, dtype: int64
# survived
# 0    30.028233
# 1    28.291433
# Name: age, dtype: float64
# survived
# 0    1390
# 1     667
# Name: pclass, dtype: int64
# survived
# 0    549
# 1    342
# Name: pclass, dtype: int64
# survived
# 0    1390
# 1     667
# Name: pclass, dtype: int64

# %%
#Görev 16: 
df['age'] = df['age'].astype(int)
df["age"].fillna(0,inplace=True)
df["age_flag"] = df.age.apply(lambda x:1.3 if x<30 else 0)
df[df.age<70]
# Out:
#      survived  pclass     sex  age  sibsp  parch      fare embarked   class  \
# 0           0       3    male   22      1      0    7.2500        S   Third
# 1           1       1  female   38      1      0   71.2833        C   First
# 2           1       3  female   26      0      0    7.9250        S   Third
# 3           1       1  female   35      1      0   53.1000        S   First
# 4           0       3    male   35      0      0    8.0500        S   Third
# 5           0       3    male   28      0      0    8.4583        Q   Third
# 6           0       1    male   54      0      0   51.8625        S   First
# 7           0       3    male    2      3      1   21.0750        S   Third
# 8           1       3  female   27      0      2   11.1333        S   Third
# 9           1       2  female   14      1      0   30.0708        C  Second
# 10          1       3  female    4      1      1   16.7000        S   Third
# ...

# %%
#Görev 17: 
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Görev 18: 
print(df.groupby("time")["total_bill"].sum())
print(df.groupby("time")["total_bill"].mean())
print(df.groupby("time")["total_bill"].min())
print(df.groupby("time")["total_bill"].max())
# Out:
# time
# Lunch     1167.47
# Dinner    3660.30
# Name: total_bill, dtype: float64
# time
# Lunch     17.168676
# Dinner    20.797159
# Name: total_bill, dtype: float64
# time
# Lunch     7.51
# Dinner    3.07
# Name: total_bill, dtype: float64
# time
# Lunch     43.11
# Dinner    50.81
# Name: total_bill, dtype: float64

# %%
#Görev 19: 
print(df.groupby(["day","time"])["total_bill"].sum())
print(df.groupby(["day","time"])["total_bill"].min())
print(df.groupby(["day","time"])["total_bill"].max())
print(df.groupby(["day","time"])["total_bill"].mean())
# Out:
# day   time
# Thur  Lunch     1077.55
#       Dinner      18.78
# Fri   Lunch       89.92
#       Dinner     235.96
# Sat   Lunch        0.00
#       Dinner    1778.40
# Sun   Lunch        0.00
#       Dinner    1627.16
# Name: total_bill, dtype: float64
# day   time
# Thur  Lunch      7.51
#       Dinner    18.78
# Fri   Lunch      8.58
#       Dinner     5.75
# Sat   Lunch       NaN
#       Dinner     3.07
# Sun   Lunch       NaN
#       Dinner     7.25
# Name: total_bill, dtype: float64
# day   time
# Thur  Lunch     43.11
#       Dinner    18.78
# Fri   Lunch     16.27
#       Dinner    40.17
# Sat   Lunch       NaN
#       Dinner    50.81
# Sun   Lunch       NaN
#       Dinner    48.17
# Name: total_bill, dtype: float64
# day   time
# Thur  Lunch     17.664754
#       Dinner    18.780000
# Fri   Lunch     12.845714
#       Dinner    19.663333
# Sat   Lunch           NaN
#       Dinner    20.441379
# Sun   Lunch           NaN
#       Dinner    21.410000
# ...

# %%
#Görev 20: 
print("\nToplamı:")
print(df[df["time"]=="Lunch"][df.sex=="Female"][["total_bill","tip"]].sum())
print("\nMinimumu:")
print(df[df["time"]=="Lunch"][df.sex=="Female"][["total_bill","tip"]].min())
print("\nMaksimumu:")
print(df[df["time"]=="Lunch"][df.sex=="Female"][["total_bill","tip"]].max())
print("\nOrtalaması:")
print(df[df["time"]=="Lunch"][df.sex=="Female"][["total_bill","tip"]].mean())
# Out:
# Toplamı:
# total_bill    571.87
# tip            90.40
# dtype: float64
#
# Minimumu:
# total_bill    8.35
# tip           1.25
# dtype: float64
#
# Maksimumu:
# total_bill    43.11
# tip            5.17
# dtype: float64
#
# Ortalaması:
# total_bill    16.339143
# tip            2.582857
# dtype: float64
# C:\Users\90538\AppData\Local\Temp\ipykernel_5112\2749525833.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[df["time"]=="Lunch"][df.sex=="Female"][["total_bill","tip"]].sum())
# C:\Users\90538\AppData\Local\Temp\ipykernel_5112\2749525833.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[df["time"]=="Lunch"][df.sex=="Female"][["total_bill","tip"]].min())
# C:\Users\90538\AppData\Local\Temp\ipykernel_5112\2749525833.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[df["time"]=="Lunch"][df.sex=="Female"][["total_bill","tip"]].max())
# ...

# %%
#Görev 21: 
df.loc[(df["size"]>3) & (df["total_bill"]>10)].mean()
# Out:
# C:\Users\90538\AppData\Local\Temp\ipykernel_5112\4227015554.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.loc[(df["size"]>3) & (df["total_bill"]>10)].mean()
# total_bill    29.312174
# tip            4.218478
# size           4.282609
# dtype: float64

# %%
#Görev 22: 
df["total_bill_tip_sum"] = df.apply(lambda df:df["total_bill"]+df["tip"],axis=1)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_bill_tip_sum
# 0       16.99  1.01  Female     No  Sun  Dinner     2               18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3               12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3               24.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2               26.99
# 4       24.59  3.61  Female     No  Sun  Dinner     4               28.20

# %%
#Görev 23: 
female_mean = df[df.sex=="Female"]["total_bill"].mean()
male_mean = df[df.sex=="Male"]["total_bill"].mean()

def ort (df):
    if df["sex"]== "Female":
        if df["total_bill"]<female_mean:
            return 0
        elif df["total_bill"]>=female_mean:
            return 1
    else:
        if df["total_bill"]<male_mean:
            return 0
        elif df["total_bill"]>=male_mean:
            return 1

df["total_bill_flag"] = df.apply(ort,axis=1)
print(f"Kadınların Ortalaması: {female_mean}\nErkeklerin Ortalaması: {male_mean}")
df
# Out:
# Kadınların Ortalaması: 18.056896551724137
# Erkeklerin Ortalaması: 20.744076433121034
#      total_bill    tip     sex smoker   day    time  size  total_bill_tip_sum  \
# 0         16.99   1.01  Female     No   Sun  Dinner     2               18.00
# 1         10.34   1.66    Male     No   Sun  Dinner     3               12.00
# 2         21.01   3.50    Male     No   Sun  Dinner     3               24.51
# 3         23.68   3.31    Male     No   Sun  Dinner     2               26.99
# 4         24.59   3.61  Female     No   Sun  Dinner     4               28.20
# 5         25.29   4.71    Male     No   Sun  Dinner     4               30.00
# 6          8.77   2.00    Male     No   Sun  Dinner     2               10.77
# 7         26.88   3.12    Male     No   Sun  Dinner     4               30.00
# 8         15.04   1.96    Male     No   Sun  Dinner     2               17.00
# 9         14.78   3.23    Male     No   Sun  Dinner     2               18.01
# ...

# %%
(df["total_bill_flag"] == 0).sum()
# Out:
# 149

# %%
#Görev 24: 
pd.DataFrame(df.groupby(["sex","total_bill_flag"])["total_bill"].sum())
# Out:
#                         total_bill
# sex    total_bill_flag
# Male   0                   1411.60
#        1                   1845.22
# Female 0                    709.04
#        1                    861.91

# %%
#Görev 25:
sıralıdf = df.sort_values(by="total_bill_tip_sum", ascending=False)[:30]
sıralıdf.head()
# Out:
#      total_bill    tip   sex smoker  day    time  size  total_bill_tip_sum  \
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3               60.81
# 212       48.33   9.00  Male     No  Sat  Dinner     4               57.33
# 59        48.27   6.73  Male     No  Sat  Dinner     4               55.00
# 156       48.17   5.00  Male     No  Sun  Dinner     6               53.17
# 182       45.35   3.50  Male    Yes  Sun  Dinner     3               48.85
#
#      total_bill_flag
# 170                1
# 212                1
# 59                 1
# 156                1
# 182                1
